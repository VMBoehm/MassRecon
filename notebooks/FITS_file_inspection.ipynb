# %%
DATA_PATH='/home/nessa/Documents/codes/MassRecon/data/preliminary_maps'

# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
import os

# %%
hdul = fits.open(os.path.join(DATA_PATH,'k_1.fits'))

# %%
hdul.info()
# Out:
# Filename: /home/nessa/Documents/codes/MassRecon/data/preliminary_maps/k_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   (128, 128)   float32

# %%
plt.imshow(hdul[0].data)
plt.axis('off')
plt.show()
